# %% [markdown]
# # adding small graph

# %%
import graph_tool.all as gt
g = gt.collection.ns["facebook_friends"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/envs/p312/lib/python3.12/site-packages/graph_tool/collection/netzschleuder.py:74, in get_ns_network(k, token)
#      73 try:
# ---> 74     cctx = zstandard.ZstdDecompressor()
#      75 except NameError:
#
# NameError: name 'zstandard' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import graph_tool.all as gt
# ----> 2 g = gt.collection.ns["facebook_friends"]
#
# File ~/envs/p312/lib/python3.12/site-packages/graph_tool/collection/netzschleuder.py:143, in LazyNSDataDict.__getitem__(self, k)
#     141 if not super().__contains__(k):
#     142     try:
# --> 143         g = get_ns_network(k, self.token)
#     144     except urllib.error.URLError as e:
# ...
