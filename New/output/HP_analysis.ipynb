# %%
import utils as ut
# Out:
# /home/jovyan/GCL-Link-Prediction/New/output/utils.py:252: SyntaxWarning: invalid escape sequence '\c'
#   means.loc[metric, max_index[0]] = "\color{red}{"+means.loc[metric, max_index[0]]+"}"
# /home/jovyan/GCL-Link-Prediction/New/output/utils.py:253: SyntaxWarning: invalid escape sequence '\c'
#   means.loc[metric, max_index[1]] = "\color{blue}{"+means.loc[metric, max_index[1]]+"}"
# /home/jovyan/GCL-Link-Prediction/New/output/utils.py:254: SyntaxWarning: invalid escape sequence '\c'
#   means.loc[metric, max_index[2]] = "\color{violet}{"+means.loc[metric, max_index[2]]+"}"

# %%
data = ut.res_load('cora_res', 'HP')
tab, mean = ut.split_methods(data, '_mean')
mean
# Out:
# metrics                                         Hits@20         Hits@50  \
# baseline,enc:gcn_ncn,pred:mlp_mean       64.09$\pm$1.28  76.75$\pm$1.06
# grace,enc:gcn_ncn,pred:mlp,random_mean   59.33$\pm$4.21    75.5$\pm$2.2
# grace,enc:gcn_ncn,pred:mlp,deg_mean      51.17$\pm$4.35  70.56$\pm$4.82
# grace,enc:gcn_ncn,pred:mlp,evc_mean      59.91$\pm$4.98   76.9$\pm$2.96
# grace,enc:gcn_ncn,pred:mlp,pr_mean       55.89$\pm$3.79   73.9$\pm$1.94
# bgrl,enc:gcn_ncn,pred:mlp,random_mean    57.29$\pm$3.63  73.65$\pm$2.11
# bgrl,enc:gcn_ncn,pred:mlp,deg_mean       50.55$\pm$3.23  65.72$\pm$2.68
# bgrl,enc:gcn_ncn,pred:mlp,evc_mean       63.76$\pm$3.93   76.8$\pm$2.12
# bgrl,enc:gcn_ncn,pred:mlp,pr_mean        50.34$\pm$4.63  71.58$\pm$3.19
# lbgrl,enc:gcn_ncn,pred:mlp,random_mean   51.59$\pm$3.26  70.86$\pm$2.62
# lbgrl,enc:gcn_ncn,pred:mlp,deg_mean      53.88$\pm$7.45  72.17$\pm$5.34
# lbgrl,enc:gcn_ncn,pred:mlp,evc_mean      49.86$\pm$5.27  69.06$\pm$4.46
# ...
