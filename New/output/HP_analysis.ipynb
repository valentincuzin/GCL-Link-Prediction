# %%
import utils as ut
import pandas as pd
import numpy as np

# %%
names = [
    '95/_USAir.csv',
    '95/_NS.csv',
    '95/_PB.csv',
    '95/_Yeast.csv',
    '95/_Celegans.csv',
    '95/_power.csv',
    '95/_Router.csv',
    '95/_Ecoli.csv',
]
data1, res1 = ut.mix_dataset(names, 'Hits@50', filtre=['grace'])
combined_data = ut.tex_table(data1, res1)
combined_data.T
# Out:
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllllll}
# \toprule
#  & 95/_USAir.csv & 95/_NS.csv & 95/_PB.csv & 95/_Yeast.csv & 95/_Celegans.csv & 95/_power.csv & 95/_Router.csv & 95/_Ecoli.csv \\
# \midrule
# grace,enc:gcn bgrl,pred:mlp,random & \color{violet}{98.57$\pm$1.5 $\bigstar$} & 96.77$\pm$2.16 $\bigstar$ & 71.22$\pm$4.29 X & 90.13$\pm$1.24 & 97.58$\pm$2.18 $\bigstar$ & 77.61$\pm$3.59 & 81.47$\pm$2.91 & 91.33$\pm$1.49 \\
# grace,enc:gcn bgrl,pred:mlp,sbm fast & 93.02$\pm$3.27 X & 92.8$\pm$2.91 X & \color{violet}{82.12$\pm$2.57 $\bigstar$} & 83.0$\pm$1.48 X & 97.27$\pm$2.09 & 66.07$\pm$2.79 X & 59.04$\pm$4.87 & 89.48$\pm$1.48 X \\
# grace,enc:gcn bgrl,pred:mlp,sbm fast2 & 92.38$\pm$6.71 X & 94.51$\pm$3.1 & \color{blue}{82.18$\pm$3.25 $\bigstar$} & 88.41$\pm$1.56 X & 93.28$\pm$2.89 X & 80.28$\pm$3.24 & 53.45$\pm$5.32 X & 91.97$\pm$1.26 \\
# ...

# %%
mplp_score = pd.DataFrame(data=
    {
        'CN*': ['80.52$\pm$4.07', '74$\pm$1.98', '37.22$\pm$3.52', '72.6$\pm$3.85', '47.67$\pm$10.87', '11.57$\pm$0.55', '9.38$\pm$1.05', '51.74$\pm$2.7'],
        'AA*': ['85.51$\pm$2.25', '74$\pm$1.98', '39.48$\pm$3.53', '73.62$\pm$1.01', '58.34$\pm$2.88', '11.57$\pm$0.55', '9.38$\pm$1.05', '68.13$\pm$1.61'],
        'RA*': ['85.95$\pm$1.83', '74$\pm$1.98', '39.84$\pm$3.54', '73.62$\pm$1.01', '61.47$\pm$4.59', '11.57$\pm$0.55', '9.38$\pm$1.05', '74.45$\pm$0.55'],
        'GCN*': ['73.29$\pm$4.70', '78.32$\pm$2.57', '37.32$\pm$4.69', '73.15$\pm$2.41', '40.68$\pm$5.45', '15.40$\pm$2.90', '24.42$\pm$4.59', '61.02$\pm$11.91',],
        'SEAL*': ['90.47$\pm$3.00', '86.59$\pm$3.03', '44.47$\pm$2.86', '83.92$\pm$1.17', '64.80$\pm$4.23', '31.46$\pm$3.25', '61.00$\pm$10.10', '83.42$\pm$1.01',],
        'ELPH*': ['87.60$\pm$1.49', '88.49$\pm$2.14', '46.91$\pm$2.21', '82.74$\pm$1.19', '64.45$\pm$3.91', '26.61$\pm$1.73', '61.07$\pm$3.06', '75.25$\pm$1.44',],
        'NCNC*': ['86.16$\pm$1.77', '83.18$\pm$3.17', '46.85$\pm$3.18', '82.00$\pm$0.97', '60.49$\pm$5.09', '23.28$\pm$1.55', '52.45$\pm$8.77', '83.94$\pm$1.57',],
        'MPLP*': ['92.12$\pm$2.21', '90.02$\pm$2.04', '52.55$\pm$2.90', '85.36$\pm$0.72', '74.28$\pm$2.09', '32.66$\pm$3.58', '64.68$\pm$3.14', '86.11$\pm$0.83',],
        'MPLP+*': ['91.24$\pm$2.11', '88.91$\pm$2.04', '51.81$\pm$2.39', '84.95$\pm$0.66', '72.73$\pm$2.99', '31.86$\pm$2.59', '60.94$\pm$2.51', '87.07$\pm$0.89',],
    }
)

tbgrl_score = pd.DataFrame(data=
    {
        'GCN*': ['81.6$\pm$1.3', '82.2$\pm$1.17', '64.2$\pm$2.9', '42.6$\pm$3.6', '76.2$\pm$1', '79.8$\pm$1.8'],
        'GRACE*': ['68.6$\pm$5.6', '70.7$\pm$6.8', '48.6$\pm$2.5', '24$\pm$2.7', '45.6$\pm$6.6', np.nan],
        'BGRL*': ['79.2$\pm$1.5', '85.8$\pm$2', '56.2$\pm$1.3', '34.6$\pm$1.8', '51.5$\pm$1.6', '47.6$\pm$1.5'],
        'T-BGRL*': ['77.3$\pm$2', '86.8$\pm$2.3', '51.7$\pm$1.6', '31.5$\pm$1.5', '55.5$\pm$0.9', '47.1$\pm$2.1'],
    }
)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:5: SyntaxWarning: invalid escape sequence '\p'
# <>:5: SyntaxWarning: invalid escape sequence '\p'
# <>:5: SyntaxWarning: invalid escape sequence '\p'
# ...

# %%
# tab 1 non -attr
names1  = [
    '70_first/_USAir.csv',
    '70_first/_NS.csv',
    '70_first/_PB.csv',
    '70_first/_Yeast.csv',
    '70_first/_Celegans.csv',
    '70_first/_power.csv',
    '70_first/_Router.csv',
    '70_first/_Ecoli.csv',
]
names2 = [
    '70_first/a_USAir.csv',
    '70_first/a_NS.csv',
    '70_first/a_PB.csv',
    '70_first/a_Yeast.csv',
    '70_first/a_Celegans.csv',
    '70_first/a_power.csv',
    '70_first/a_Router.csv',
    '70_first/a_Ecoli.csv',
]
names3 = [
    '70_first/b_USAir.csv',
    '70_first/b_NS.csv',
    '70_first/b_PB.csv',
    '70_first/b_Yeast.csv',
    '70_first/b_Celegans.csv',
    '70_first/b_power.csv',
    '70_first/b_Router.csv',
    '70_first/b_Ecoli.csv',
]
names4 = [
    '70_first/c_USAir.csv',
    '70_first/c_NS.csv',
    '70_first/c_PB.csv',
    '70_first/c_Yeast.csv',
    '70_first/c_Celegans.csv',
    '70_first/c_power.csv',
    '70_first/c_Router.csv',
    '70_first/c_Ecoli.csv',
]
data1, res1 = ut.mix_dataset(names1, 'Hits@50', filtre2=['\+', 'prob', 'cheat'])
data2, res2 = ut.mix_dataset(names2, 'Hits@50', filtre2=['\+', 'prob', 'cheat'])
data3, res3 = ut.mix_dataset(names3, 'Hits@50', filtre2=['prob', 'cheat'])
data4, res4 = ut.mix_dataset(names4, 'Hits@50', filtre2=['prob', 'cheat'])

power_data, power_res = ut.mix_dataset(['70_first/d_power.csv'], 'Hits@50', filtre2=['\+', 'prob', 'cheat'])
power_data.index =  ['70_first/_power.csv']

mplp_score.index = data1.index
data2.index = data1.index
data3.index = data1.index
data4.index = data1.index

res2.index = res1.index
res3.index = res1.index
res4.index = res1.index

power_data = pd.concat([mplp_score.loc['70_first/_power.csv'].to_frame().T, power_data], axis=1)
combined_data = pd.concat([mplp_score, data1, data2, data3, data4], axis=1)
combined_data.loc['70_first/_power.csv'] = power_data.loc['70_first/_power.csv']
combined_res = pd.concat([res1, res2, res3, res4], axis=1)
combined_res.loc['70_first/_power.csv'] = power_res.loc['70_first/d_power.csv']
combined_data = ut.tex_table(combined_data, combined_res)
combined_data.T
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\+'
# <>:43: SyntaxWarning: invalid escape sequence '\+'
# <>:47: SyntaxWarning: invalid escape sequence '\+'
# <>:42: SyntaxWarning: invalid escape sequence '\+'
# <>:43: SyntaxWarning: invalid escape sequence '\+'
# <>:47: SyntaxWarning: invalid escape sequence '\+'
# /tmp/ipykernel_263/1822799127.py:42: SyntaxWarning: invalid escape sequence '\+'
#   data1, res1 = ut.mix_dataset(names1, 'Hits@50', filtre2=['\+', 'prob', 'cheat'])
# /tmp/ipykernel_263/1822799127.py:43: SyntaxWarning: invalid escape sequence '\+'
#   data2, res2 = ut.mix_dataset(names2, 'Hits@50', filtre2=['\+', 'prob', 'cheat'])
# /tmp/ipykernel_263/1822799127.py:47: SyntaxWarning: invalid escape sequence '\+'
#   power_data, power_res = ut.mix_dataset(['70_first/d_power.csv'], 'Hits@50', filtre2=['\+', 'prob', 'cheat'])
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllllll}
# \toprule
# ...

# %%
# tab 1 non -attr
names1  = [
    '70_first/_USAir.csv',
    '70_first/_NS.csv',
    '70_first/_PB.csv',
    '70_first/_Yeast.csv',
    '70_first/_Celegans.csv',
    '70_first/_power.csv',
    '70_first/_Router.csv',
    '70_first/_Ecoli.csv',
]
names2 = [
    '70_first/a_USAir.csv',
    '70_first/a_NS.csv',
    '70_first/a_PB.csv',
    '70_first/a_Yeast.csv',
    '70_first/a_Celegans.csv',
    '70_first/a_power.csv',
    '70_first/a_Router.csv',
    '70_first/a_Ecoli.csv',
]
names3 = [
    '70_first/b_USAir.csv',
    '70_first/b_NS.csv',
    '70_first/b_PB.csv',
    '70_first/b_Yeast.csv',
    '70_first/b_Celegans.csv',
    '70_first/b_power.csv',
    '70_first/b_Router.csv',
    '70_first/b_Ecoli.csv',
]
names4 = [
    '70_first/c_USAir.csv',
    '70_first/c_NS.csv',
    '70_first/c_PB.csv',
    '70_first/c_Yeast.csv',
    '70_first/c_Celegans.csv',
    '70_first/c_power.csv',
    '70_first/c_Router.csv',
    '70_first/c_Ecoli.csv',
]
data1, res1 = ut.mix_dataset(names1, 'Hits@50', filtre=['sbm'], filtre2=['\+', 'prob'])
data2, res2 = ut.mix_dataset(names2, 'Hits@50', filtre=['sbm'], filtre2=['\+', 'prob'])
data3, res3 = ut.mix_dataset(names3, 'Hits@50', filtre=['sbm'], filtre2=['prob'])
data4, res4 = ut.mix_dataset(names4, 'Hits@50', filtre=['sbm'], filtre2=['prob'])

power_data, power_res = ut.mix_dataset(['70_first/d_power.csv'], 'Hits@50', filtre=['sbm'], filtre2=['\+', 'prob'])
power_data.index =  ['70_first/_power.csv']

mplp_score.index = data1.index
data2.index = data1.index
data3.index = data1.index
data4.index = data1.index

res2.index = res1.index
res3.index = res1.index
res4.index = res1.index

combined_data = pd.concat([mplp_score, data1, data2, data3, data4], axis=1)
power_data = pd.concat([mplp_score.loc['70_first/_power.csv'].to_frame().T, power_data], axis=1)
combined_data.loc['70_first/_power.csv'] = power_data.loc['70_first/_power.csv']
combined_res = pd.concat([res1, res2, res3, res4], axis=1)
combined_res.loc['70_first/_power.csv'] = power_res.loc['70_first/d_power.csv']
combined_data = ut.tex_table(combined_data, combined_res)
combined_data.T
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\+'
# <>:43: SyntaxWarning: invalid escape sequence '\+'
# <>:47: SyntaxWarning: invalid escape sequence '\+'
# <>:42: SyntaxWarning: invalid escape sequence '\+'
# <>:43: SyntaxWarning: invalid escape sequence '\+'
# <>:47: SyntaxWarning: invalid escape sequence '\+'
# /tmp/ipykernel_263/3779004615.py:42: SyntaxWarning: invalid escape sequence '\+'
#   data1, res1 = ut.mix_dataset(names1, 'Hits@50', filtre=['sbm'], filtre2=['\+', 'prob'])
# /tmp/ipykernel_263/3779004615.py:43: SyntaxWarning: invalid escape sequence '\+'
#   data2, res2 = ut.mix_dataset(names2, 'Hits@50', filtre=['sbm'], filtre2=['\+', 'prob'])
# /tmp/ipykernel_263/3779004615.py:47: SyntaxWarning: invalid escape sequence '\+'
#   power_data, power_res = ut.mix_dataset(['70_first/d_power.csv'], 'Hits@50', filtre=['sbm'], filtre2=['\+', 'prob'])
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllllll}
# \toprule
# ...

# %%
data2.loc["85_second/_photo.csv"].fillna(photo_end_data.loc["85_second/_photo.csv"])
# Out:
# csgcl,enc:gcn_bgrl,pred:mlp,random_mean        55.82$\pm$4.02
# csgcl,enc:gcn_bgrl,pred:mlp,deg_mean           60.37$\pm$2.47
# csgcl,enc:gcn_bgrl,pred:mlp,evc_mean           55.07$\pm$2.19
# csgcl,enc:gcn_bgrl,pred:mlp,pr_mean            62.72$\pm$3.16
# csgcl,enc:gcn_bgrl,pred:mlp,scom_mean           65.4$\pm$2.95
# csgcl,enc:gcn_bgrl,pred:mlp,sbm_fast_mean                 NaN
# csgcl,enc:gcn_bgrl,pred:mlp,sbm_fast2_mean                NaN
# lbgrl,enc:gcn_bgrl,pred:mlp,random_mean         56.5$\pm$3.14
# lbgrl,enc:gcn_bgrl,pred:mlp,deg_mean           52.99$\pm$3.19
# lbgrl,enc:gcn_bgrl,pred:mlp,evc_mean           61.86$\pm$3.57
# lbgrl,enc:gcn_bgrl,pred:mlp,pr_mean            61.98$\pm$3.47
# lbgrl,enc:gcn_bgrl,pred:mlp,scom_mean          51.26$\pm$2.92
# lbgrl,enc:gcn_bgrl,pred:mlp,sbm_fast_mean      47.69$\pm$4.21
# lbgrl,enc:gcn_bgrl,pred:mlp,sbm_fast2_mean     36.29$\pm$4.56
# lgrace,enc:gcn_bgrl,pred:mlp,random_mean                  NaN
# ...

# %%
names1 = [
    "85_second/_cora.csv",
    '85_second/_citeseer.csv',
    "85_second/_cs.csv",
    "85_second/_physics.csv",
    "85_second/_computers.csv",
    "85_second/_photo.csv"
]

names2 = [
    "85_second/2_cora.csv",
    '85_second/2_citeseer.csv',
    "85_second/2_cs.csv",
    "85_second/2_physics.csv",
    "85_second/2_computers.csv",
    "85_second/2_photo.csv"
]
data1, res1 = ut.mix_dataset(names1, 'Hits@50', filtre2=['prob', 'cheat'])
data2, res2 = ut.mix_dataset(names2, 'Hits@50', filtre2=['prob', 'cheat'])
physics_end_data, physics_end_res = ut.mix_dataset(['85_second/3_physics.csv'], 'Hits@50', filtre2=['prob', 'cheat'])
photo_end_data, photo_end_res = ut.mix_dataset(['85_second/3_photo.csv'], 'Hits@50', filtre2=['prob', 'cheat'])
photo2_end_data, photo2_end_res = ut.mix_dataset(['85_second/4_photo.csv'], 'Hits@50', filtre2=['prob', 'cheat'])

tbgrl_score.index = data1.index
physics_end_data.index = ["85_second/_physics.csv"]
physics_end_res.index = ["85_second/_physics.csv"]
photo_end_data.index = ["85_second/_photo.csv"]
photo_end_res.index = ["85_second/_photo.csv"]
photo2_end_data.index = ["85_second/_photo.csv"]
photo2_end_res.index = ["85_second/_photo.csv"]
data2.index = data1.index
res2.index = res1.index

data1.loc["85_second/_physics.csv"].fillna(physics_end_data.loc["85_second/_physics.csv"], inplace=True)
data2.loc["85_second/_photo.csv"].fillna(photo_end_data.loc["85_second/_photo.csv"], inplace=True)
data2.loc["85_second/_photo.csv"].fillna(photo2_end_data.loc["85_second/_photo.csv"], inplace=True)

res1.loc["85_second/_physics.csv"].fillna(physics_end_res.loc["85_second/_physics.csv"], inplace=True)
res2.loc["85_second/_photo.csv"].fillna(photo_end_res.loc["85_second/_photo.csv"], inplace=True)
res2.loc["85_second/_photo.csv"].fillna(photo2_end_res.loc["85_second/_photo.csv"], inplace=True)

combined_data = pd.concat([tbgrl_score, data1, data2,], axis=1)
combined_res = pd.concat([res1, res2], axis=1)

data = ut.tex_table(combined_data, combined_res)
data.T
# Out:
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllll}
# \toprule
#  & 85_second/_cora.csv & 85_second/_citeseer.csv & 85_second/_cs.csv & 85_second/_physics.csv & 85_second/_computers.csv & 85_second/_photo.csv \\
# \midrule
# GCN* & 81.6$\pm$1.3 & 82.2$\pm$1.17 & 64.2$\pm$2.9 & 42.6$\pm$3.6 & \color{red}{76.2$\pm$1} & \color{red}{79.8$\pm$1.8} \\
# GRACE* & 68.6$\pm$5.6 & 70.7$\pm$6.8 & 48.6$\pm$2.5 & 24$\pm$2.7 & 45.6$\pm$6.6 & NaN \\
# BGRL* & 79.2$\pm$1.5 & 85.8$\pm$2 & 56.2$\pm$1.3 & 34.6$\pm$1.8 & 51.5$\pm$1.6 & 47.6$\pm$1.5 \\
# T-BGRL* & 77.3$\pm$2 & 86.8$\pm$2.3 & 51.7$\pm$1.6 & 31.5$\pm$1.5 & \color{blue}{55.5$\pm$0.9} & 47.1$\pm$2.1 \\
# baseline,enc:gcn bgrl,pred:mlp & 81.97$\pm$2.31 & 75.01$\pm$3.03 X & \color{red}{83.89$\pm$1.28 $\bigstar$} & \color{red}{83.9$\pm$1.31 $\bigstar$} & \color{violet}{51.81$\pm$3.74 $\bigstar$} & \color{blue}{67.23$\pm$4.1 $\bigstar$} \\
# ...

# %%
names1  = [
    '70_first/_cora.csv',
    '70_first/_citeseer.csv',
    '70_first/_USAir.csv',
    '70_first/_NS.csv',
    '70_first/_PB.csv',
    '70_first/_Yeast.csv',
    '70_first/_Celegans.csv',
    '70_first/_power.csv',
    '70_first/_Router.csv',
    '70_first/_Ecoli.csv',
]
names2 = [
    '70_first/a_cora.csv',
    '70_first/a_citeseer.csv',
    '70_first/a_USAir.csv',
    '70_first/a_NS.csv',
    '70_first/a_PB.csv',
    '70_first/a_Yeast.csv',
    '70_first/a_Celegans.csv',
    '70_first/a_power.csv',
    '70_first/a_Router.csv',
    '70_first/a_Ecoli.csv',
]
data1, res1 = ut.mix_dataset(names1, 'Hits@50', filtre=['sbm'])
data2, res2 = ut.mix_dataset(names2, 'Hits@50')
data2.index = data.index
combined_data = pd.concat([data, data2], axis=1)
# combined_data = ut.tex_table(combined_data, res)

def rename(idx):
    print(idx)
    if 'mlp,' in idx:
        return idx.split('mlp,')[1]
    else:
        return idx
import numpy as np
combined_data = combined_data.T.rename(index=rename)
for column in combined_data.columns:
        combined_data[column] = combined_data[column].apply(ut.extract_mean).apply(np.mean)
combined_data = combined_data.groupby(combined_data.index).mean()
combined_data['Moyenne'] = combined_data.mean(axis=1)
combined_data = combined_data.sort_values(by='Moyenne')
combined_data
# Out:
# bgrl,enc:gcn_bgrl,pred:mlp,sbm_fast+random_mean
# bgrl,enc:gcn_bgrl,pred:mlp,sbm_fast_cheat+random_mean
# grace,enc:gcn_bgrl,pred:mlp,sbm_fast+random_mean
# grace,enc:gcn_bgrl,pred:mlp,sbm_fast_cheat+random_mean
# lbgrl,enc:gcn_bgrl,pred:mlp,sbm_fast+random_mean
# lbgrl,enc:gcn_bgrl,pred:mlp,sbm_fast_cheat+random_mean
# lgrace,enc:gcn_bgrl,pred:mlp,sbm_fast+random_mean
# lgrace,enc:gcn_bgrl,pred:mlp,sbm_fast_cheat+random_mean
# infomap_prob_pred_mean
# bgrl,enc:gcn_bgrl,pred:mlp,sbm_fast_mean
# louvain_prob_pred_mean
# bgrl,enc:gcn_bgrl,pred:mlp,sbm_fast+deg_mean
# bgrl,enc:gcn_bgrl,pred:mlp,sbm_fast+evc_mean
# bgrl,enc:gcn_bgrl,pred:mlp,sbm_fast+pr_mean
# bgrl,enc:gcn_bgrl,pred:mlp,sbm_fast+scom_mean
# bgrl,enc:gcn_bgrl,pred:mlp,sbm_fast2_mean
# grace,enc:gcn_bgrl,pred:mlp,sbm_fast_mean
# leiden_prob_pred_mean
# grace,enc:gcn_bgrl,pred:mlp,sbm_fast+deg_mean
# grace,enc:gcn_bgrl,pred:mlp,sbm_fast+evc_mean
# grace,enc:gcn_bgrl,pred:mlp,sbm_fast+pr_mean
# ...

# %%
# tab 2 
names  = [
    '85_second/_cora.csv',
    '85_second/_citeseer.csv',
    '85_second/_USAir.csv',
    '85_second/_NS.csv',
    '85_second/_PB.csv',
    '85_second/_Yeast.csv',
    '85_second/_Celegans.csv',
    '85_second/_power.csv',
    '85_second/_Router.csv',
    '85_second/_Ecoli.csv',
]

data1, res1 = ut.mix_dataset(names, 'Hits@50', filtre2=['cheat'])
data1 = data1.T

names  = [
    '70_first/_cora.csv',
    '70_first/_citeseer.csv',
    '70_first/_USAir.csv',
    '70_first/_NS.csv',
    '70_first/_PB.csv',
    '70_first/_Yeast.csv',
    '70_first/_Celegans.csv',
    '70_first/_power.csv',
    '70_first/_Router.csv',
    '70_first/_Ecoli.csv',
]
names2 = [
    '70_first/a_cora.csv',
    '70_first/a_citeseer.csv',
    '70_first/a_USAir.csv',
    '70_first/a_NS.csv',
    '70_first/a_PB.csv',
    '70_first/a_Yeast.csv',
    '70_first/a_Celegans.csv',
    '70_first/a_power.csv',
    '70_first/a_Router.csv',
    '70_first/a_Ecoli.csv',
]
data, res = ut.mix_dataset(names, 'Hits@50', filtre=['baseline', 'random'], filtre2=['louvain', 'leiden', 'infomap', '\+', 'cheat'])
data2, res2 = ut.mix_dataset(names2, 'Hits@50', filtre2=['\+'])
data2.index = data.index
combined_data = pd.concat([data, data2], axis=1)
combined_data = combined_data.T

data1.columns = combined_data.columns
display(combined_data)
display(data1)

for column in combined_data.columns:
        combined_data[column] = combined_data[column].apply(ut.extract_mean).apply(np.mean)

for column in data1.columns:
        data1[column] = data1[column].apply(ut.extract_mean).apply(np.mean)
tab2 = data1 - combined_data
tab2 = tab2.groupby(tab2.index).mean()
tab2['Moyenne'] = tab2.mean(axis=1)
tab2 = tab2.sort_values(by='Moyenne')
tab2
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\+'
# <>:43: SyntaxWarning: invalid escape sequence '\+'
# <>:42: SyntaxWarning: invalid escape sequence '\+'
# <>:43: SyntaxWarning: invalid escape sequence '\+'
# /tmp/ipykernel_10022/1523198393.py:42: SyntaxWarning: invalid escape sequence '\+'
#   data, res = ut.mix_dataset(names, 'Hits@50', filtre=['baseline', 'random'], filtre2=['louvain', 'leiden', 'infomap', '\+', 'cheat'])
# /tmp/ipykernel_10022/1523198393.py:43: SyntaxWarning: invalid escape sequence '\+'
#   data2, res2 = ut.mix_dataset(names2, 'Hits@50', filtre2=['\+'])
#                                             70_first/_cora.csv  \
# baseline,enc:gcn_bgrl,pred:mlp_mean               65.8$\pm$1.5
# bgrl,enc:gcn_bgrl,pred:mlp,random_mean          68.63$\pm$3.05
# grace,enc:gcn_bgrl,pred:mlp,random_mean         68.47$\pm$2.82
# lbgrl,enc:gcn_bgrl,pred:mlp,random_mean         68.31$\pm$2.88
# lgrace,enc:gcn_bgrl,pred:mlp,random_mean        59.44$\pm$3.72
# ...

# %%
names = [
    'POS/_crime.csv',
    'POS/_euroroad.csv',
    'POS/_netscience.csv',
    'POS/_power.csv',
    'POS/_wiki_science.csv',
    'POS/_yeast.csv',
]
data, res = ut.mix_dataset(names, 'Hits@50', filtre=['pred:mlp', 'baseline'], filtre2=['bgrl,enc'])
data = ut.tex_table(data,res)
data.T
# Out:
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllll}
# \toprule
#  & POS/_crime.csv & POS/_euroroad.csv & POS/_netscience.csv & POS/_power.csv & POS/_wiki_science.csv & POS/_yeast.csv \\
# \midrule
# baseline,enc:gcn bgrl,pred:inner & 31.02$\pm$4.46 & \color{blue}{70.42$\pm$3.53 $\bigstar$} & \color{blue}{83.1$\pm$1.35} & \color{violet}{50.3$\pm$1.83} & 89.01$\pm$1.27 & 92.92$\pm$0.75 X \\
# baseline,enc:gcn bgrl,pred:mlp & \color{violet}{37.73$\pm$4.45} & 27.99$\pm$3.97 X & 75.89$\pm$1.8 X & 30.16$\pm$0.71 X & \color{red}{90.78$\pm$1.31 $\bigstar$} & 93.45$\pm$0.43 \\
# baseline,enc:gcn bgrl,pred:ncn & 27.53$\pm$2.99 X & 34.06$\pm$4.6 & 79.51$\pm$1.83 & 24.07$\pm$1.74 X & 86.91$\pm$4.19 & 93.65$\pm$0.35 \\
# grace,enc:gcn bgrl,pred:mlp,random & 28.44$\pm$4.99 X & 34.17$\pm$2.83 & 79.01$\pm$4.05 & 36.63$\pm$1.5 & 86.42$\pm$1.98 & \color{blue}{93.83$\pm$0.44} \\
# ...

# %%
names = [
    'SBM/Important_cora.csv',
    'SBM/Important2_cora.csv',
    'SBM/Important_NS.csv',
    'SBM/Important2_NS.csv'
]
data, res = ut.mix_dataset(names, 'Hits@100', filtre=['pred:mlp', 'baseline'], )
data = ut.tex_table(data,res)
data.T
# Out:
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllll}
# \toprule
#  & SBM/Important_cora.csv & SBM/Important2_cora.csv & SBM/Important_NS.csv & SBM/Important2_NS.csv \\
# \midrule
# baseline,enc:gcn bgrl,pred:inner & \color{blue}{85.72$\pm$1.15 $\bigstar$} & 91.23$\pm$1.31 & \color{violet}{89.87$\pm$1.34} & \color{violet}{94.27$\pm$1.8} \\
# baseline,enc:gcn bgrl,pred:mlp & 74.33$\pm$1.39 X & 88.65$\pm$1.13 & 81.95$\pm$1.88 & 94.23$\pm$1.64 \\
# baseline,enc:gcn bgrl,pred:ncn & 78.45$\pm$1.8 & 48.58$\pm$13.99 X & 83.41$\pm$1.25 & 84.27$\pm$8.47 X \\
# grace,enc:gcn bgrl,pred:mlp,random & \color{violet}{82.88$\pm$1.1} & 89.39$\pm$1.48 & 85.6$\pm$1.76 & 93.83$\pm$2.04 \\
# grace,enc:gcn bgrl,pred:mlp,sbm fast+random & 58.3$\pm$3.1 X & 90.06$\pm$1.38 & 79.2$\pm$1.65 X & 92.45$\pm$1.08 \\
# ...

# %%
names = [
    'HP/USAir_res.csv',
    'HP/NS_res.csv',
    'HP/PB_res.csv',
    'HP/Yeast_res.csv',
    'HP/Celegans_res.csv',
    'HP/Power_res.csv',
    'HP/Router_res.csv',
    'HP/Ecoli_res.csv'
]
data, res = ut.mix_dataset(names, 'Hits@50')
data = ut.tex_table(data,res)
data.T
# Out:
# <class 'pandas.core.series.Series'> metrics
# Hits@20          [0.84941176 0.87058824 0.80705882 0.83294118 0...
# Hits@50          [0.90588235 0.90823529 0.87294118 0.92       0...
# Hits@100         [0.94352941 0.93411765 0.93882353 0.95764706 0...
# ROCAUC           [0.95338408 0.95022837 0.94849612 0.95899001 0...
# AP               [0.96082442 0.96228751 0.95655739 0.96665544 0...
# pretrain_time                                                   []
# Name: baseline,enc:gcn_ncn,pred:mlp, dtype: object
# <class 'pandas.core.series.Series'> metrics
# Hits@20          [0.86117647 0.80235294 0.70823529 0.83764706 0...
# Hits@50          [0.92235294 0.87764706 0.83529412 0.88941176 0...
# Hits@100         [0.95764706 0.92705882 0.92705882 0.92235294 0...
# ROCAUC           [0.96032664 0.94667958 0.93026082 0.94280244 0...
# AP               [0.96547968 0.95528226 0.93785467 0.95509052 0...
# pretrain_time    [7.11123419 7.11418986 7.09919715 7.06552982 7...
# ...

# %%
data1 = ut.res_load('HP/L_pubmed.csv')
data2 = ut.res_load('HP/pubmed_res.csv')
data2 = data2.T.join(data1.T)
data2.to_csv('HP/pubmed_res.csv', sep=';')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 data1 = ut.res_load('HP/L_pubmed.csv')
#       2 data2 = ut.res_load('HP/pubmed_res.csv')
# ----> 3 data2 = data2.T.join(data1.T)
#       4 data2.to_csv('HP/pubmed_res.csv', sep=';')
#
# File ~/envs/gt/lib/python3.13/site-packages/pandas/core/frame.py:10764, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10754     if how == "cross":
#   10755         return merge(
#   10756             self,
#   10757             other,
#    (...)  10762             validate=validate,
#   10763         )
# > 10764     return merge(
#   10765         self,
#   10766         other,
#   10767         left_on=on,
#   10768         how=how,
#   10769         left_index=on is None,
#   10770         right_index=True,
#   10771         suffixes=(lsuffix, rsuffix),
#   10772         sort=sort,
# ...

# %%
names = [
    'HP/cora_res.csv',
    'HP/citeseer_res.csv',
    'HP/pubmed_res.csv'
]
data, res = ut.mix_dataset(names, 'Hits@100')
data = ut.tex_table(data,res)
display(data.T)
# Out:
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llll}
# \toprule
#  & HP/cora_res.csv & HP/citeseer_res.csv & HP/pubmed_res.csv \\
# \midrule
# baseline,enc:gcn ncn,pred:mlp & \color{violet}{85.74$\pm$0.95} & 85.66$\pm$2.07 & \color{red}{81.38$\pm$1.66 $\bigstar$} \\
# grace,enc:gcn ncn,pred:mlp,random & 84.04$\pm$0.76 & 89.56$\pm$1.55 & 75.06$\pm$1.22 \\
# grace,enc:gcn ncn,pred:mlp,deg & 84.31$\pm$2.6 & 90.22$\pm$0.98 & 75.36$\pm$1.67 \\
# grace,enc:gcn ncn,pred:mlp,evc & \color{red}{87.1$\pm$1.76 $\bigstar$} & \color{red}{92.66$\pm$1.28 $\bigstar$} & 75.85$\pm$2.05 \\
# grace,enc:gcn ncn,pred:mlp,pr & 84.63$\pm$1.54 & \color{blue}{90.3$\pm$1.03} & \color{violet}{79.88$\pm$1.66} \\
# bgrl,enc:gcn ncn,pred:mlp,random & 84.33$\pm$1.29 & 87.99$\pm$2.26 & 72.81$\pm$2.49 \\
# bgrl,enc:gcn ncn,pred:mlp,deg & 76.12$\pm$1.52 X & 85.66$\pm$17.82 & 75.35$\pm$1.69 \\
# bgrl,enc:gcn ncn,pred:mlp,evc & 84.69$\pm$1.0 & 88.69$\pm$1.59 & 78.04$\pm$1.06 \\
# ...

# %%
names = [
    'HP_SBM/_Celegans.csv',
    'HP_SBM/_USAir.csv'
]
data, res = ut.mix_dataset(names, 'Hits@50')
data = ut.tex_table(data,res)
display(data.T)
# Out:
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lll}
# \toprule
#  & HP_SBM/_Celegans.csv & HP_SBM/_USAir.csv \\
# \midrule
# louvain prob pred & 32.28$\pm$3.88 X & 47.18$\pm$5.16 X \\
# grace,enc:gcn ncn,pred:mlp,sbm & 64.78$\pm$4.89 & 90.02$\pm$2.26 \\
# grace,enc:gcn ncn,pred:mlp,sbm+random & 67.74$\pm$2.38 $\bigstar$ & 86.16$\pm$3.96 \\
# grace,enc:gcn ncn,pred:mlp,sbm+deg & 65.94$\pm$4.76 & \color{red}{92.33$\pm$1.62 $\bigstar$} \\
# grace,enc:gcn ncn,pred:mlp,sbm+evc & \color{red}{70.51$\pm$2.72 $\bigstar$} & 87.27$\pm$2.53 \\
# grace,enc:gcn ncn,pred:mlp,sbm+pr & \color{blue}{68.23$\pm$3.54 $\bigstar$} & \color{violet}{90.75$\pm$2.05 $\bigstar$} \\
# bgrl,enc:gcn ncn,pred:mlp,sbm & 57.48$\pm$3.33 & 80.47$\pm$3.32 \\
# bgrl,enc:gcn ncn,pred:mlp,sbm+random & 54.57$\pm$6.23 & 88.19$\pm$2.18 \\
# bgrl,enc:gcn ncn,pred:mlp,sbm+deg & 57.39$\pm$4.86 & \color{blue}{91.93$\pm$2.26 $\bigstar$} \\
# bgrl,enc:gcn ncn,pred:mlp,sbm+evc & 63.8$\pm$4.16 & 76.59$\pm$4.02 \\
# ...

# %%
names = [
    'HP_SBM/Final_citeseer.csv',
    'HP_SBM/Final_cora.csv',
    'HP_SBM/Final_USAir.csv',
    'HP_SBM/Final_NS.csv',
    'HP_SBM/Final_PB.csv',
    'HP_SBM/Final_Yeast.csv',
    'HP_SBM/Final_Celegans.csv',
    'HP_SBM/Important3_power.csv',
    'HP_SBM/Final_Router.csv',
    'HP_SBM/Final_Ecoli.csv',
    ]
data, res = ut.mix_dataset(names, 'Hits@50', filtre2=['kmeans'])
data = ut.tex_table(data,res)
display(data.T)
# Out:
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllllllll}
# \toprule
#  & HP_SBM/Final_citeseer.csv & HP_SBM/Final_cora.csv & HP_SBM/Final_USAir.csv & HP_SBM/Final_NS.csv & HP_SBM/Final_PB.csv & HP_SBM/Final_Yeast.csv & HP_SBM/Final_Celegans.csv & HP_SBM/Important3_power.csv & HP_SBM/Final_Router.csv & HP_SBM/Final_Ecoli.csv \\
# \midrule
# louvain prob pred & 50.24$\pm$1.59 X & 52.83$\pm$1.21 X & 47.41$\pm$4.42 X & 80.71$\pm$0.99 & 4.44$\pm$0.69 X & 62.04$\pm$3.76 X & 34.99$\pm$5.17 X & 33.69$\pm$1.47 & 21.91$\pm$1.42 X & 36.44$\pm$1.02 X \\
# grace,enc:gcn bgrl,pred:mlp,sbm+random & 63.01$\pm$1.83 X & 67.97$\pm$1.48 & 89.6$\pm$2.17 & \color{red}{91.48$\pm$1.26 $\bigstar$} & \color{red}{47.95$\pm$3.38 $\bigstar$} & 76.07$\pm$1.88 & 68.16$\pm$4.08 & \color{red}{59.58$\pm$2.24 $\bigstar$} & \color{blue}{49.61$\pm$1.03 $\bigstar$} & 79.1$\pm$1.19 \\
# ...
