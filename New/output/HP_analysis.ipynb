# %%
import utils as ut

# %%
data = ut.res_load('cora_res', 'HP')
tab, mean = ut.split_methods(data, '_mean')
mean
# Out:
# metrics                                         Hits@20         Hits@50  \
# baseline,enc:gcn_ncn,pred:mlp_mean       64.09$\pm$1.28  76.75$\pm$1.06
# grace,enc:gcn_ncn,pred:mlp,random_mean   59.33$\pm$4.21    75.5$\pm$2.2
# grace,enc:gcn_ncn,pred:mlp,deg_mean      51.17$\pm$4.35  70.56$\pm$4.82
# grace,enc:gcn_ncn,pred:mlp,evc_mean      59.91$\pm$4.98   76.9$\pm$2.96
# grace,enc:gcn_ncn,pred:mlp,pr_mean       55.89$\pm$3.79   73.9$\pm$1.94
# bgrl,enc:gcn_ncn,pred:mlp,random_mean    57.29$\pm$3.63  73.65$\pm$2.11
# bgrl,enc:gcn_ncn,pred:mlp,deg_mean       50.55$\pm$3.23  65.72$\pm$2.68
# bgrl,enc:gcn_ncn,pred:mlp,evc_mean       63.76$\pm$3.93   76.8$\pm$2.12
# bgrl,enc:gcn_ncn,pred:mlp,pr_mean        50.34$\pm$4.63  71.58$\pm$3.19
# lbgrl,enc:gcn_ncn,pred:mlp,random_mean   51.59$\pm$3.26  70.86$\pm$2.62
# lbgrl,enc:gcn_ncn,pred:mlp,deg_mean      53.88$\pm$7.45  72.17$\pm$5.34
# lbgrl,enc:gcn_ncn,pred:mlp,evc_mean      49.86$\pm$5.27  69.06$\pm$4.46
# ...

# %%
data = ut.res_load('citeseer_res', 'HP')
tab, mean = ut.split_methods(data, '_mean')
mean
# Out:
# metrics                                          Hits@20          Hits@50  \
# baseline,enc:gcn_ncn,pred:mlp_mean        63.32$\pm$4.11   76.51$\pm$2.41
# grace,enc:gcn_ncn,pred:mlp,random_mean    62.86$\pm$4.24   77.75$\pm$2.62
# grace,enc:gcn_ncn,pred:mlp,deg_mean       68.93$\pm$2.45    82.6$\pm$2.02
# grace,enc:gcn_ncn,pred:mlp,evc_mean       72.62$\pm$4.76   86.05$\pm$2.19
# grace,enc:gcn_ncn,pred:mlp,pr_mean        71.12$\pm$3.65    83.3$\pm$2.52
# bgrl,enc:gcn_ncn,pred:mlp,random_mean     62.93$\pm$5.01   79.07$\pm$2.29
# bgrl,enc:gcn_ncn,pred:mlp,deg_mean       67.03$\pm$19.66  78.45$\pm$18.67
# bgrl,enc:gcn_ncn,pred:mlp,evc_mean        69.91$\pm$3.63   81.43$\pm$2.57
# bgrl,enc:gcn_ncn,pred:mlp,pr_mean        53.65$\pm$20.55  67.82$\pm$22.47
# lbgrl,enc:gcn_ncn,pred:mlp,random_mean    41.25$\pm$7.65    53.51$\pm$8.8
# lbgrl,enc:gcn_ncn,pred:mlp,deg_mean       55.85$\pm$4.65    71.2$\pm$4.21
# lbgrl,enc:gcn_ncn,pred:mlp,evc_mean       57.24$\pm$5.84   71.41$\pm$4.12
# ...

# %%
data = ut.res_load('pubmed_res', 'HP')
tab, mean = ut.split_methods(data, '_mean')
mean
# Out:
# metrics                                        Hits@20         Hits@50  \
# baseline,enc:gcn_ncn,pred:mlp_mean      51.24$\pm$4.38  70.04$\pm$3.06
# grace,enc:gcn_ncn,pred:mlp,random_mean  48.93$\pm$3.27  64.67$\pm$1.45
# grace,enc:gcn_ncn,pred:mlp,deg_mean     44.43$\pm$5.15  62.93$\pm$3.55
# grace,enc:gcn_ncn,pred:mlp,evc_mean     34.69$\pm$3.43  59.41$\pm$2.73
# grace,enc:gcn_ncn,pred:mlp,pr_mean      52.32$\pm$3.08  69.53$\pm$3.35
# bgrl,enc:gcn_ncn,pred:mlp,random_mean   31.17$\pm$5.56  54.66$\pm$3.83
# bgrl,enc:gcn_ncn,pred:mlp,deg_mean      42.91$\pm$4.44  62.68$\pm$2.96
# bgrl,enc:gcn_ncn,pred:mlp,evc_mean      52.05$\pm$3.24  68.67$\pm$2.18
# bgrl,enc:gcn_ncn,pred:mlp,pr_mean       32.16$\pm$3.53  55.05$\pm$2.62
#
# metrics                                       Hits@100          ROCAUC  \
# baseline,enc:gcn_ncn,pred:mlp_mean      81.38$\pm$1.66  98.78$\pm$0.05
# grace,enc:gcn_ncn,pred:mlp,random_mean  75.06$\pm$1.22  97.35$\pm$0.24
# ...

# %%
data = ut.res_load('cora_res', 'HP_SBM')
tab, mean = ut.split_methods(data, '_mean')
mean
# Out:
# metrics                                                 Hits@20  \
# leiden_prob_pred_mean                            37.82$\pm$4.84
# grace,enc:gcn_ncn,pred:mlp,sbm+random_mean       49.21$\pm$2.84
# grace,enc:gcn_ncn,pred:mlp,sbm_fast+random_mean  53.42$\pm$4.43
# grace,enc:gcn_ncn,pred:mlp,sbm_fast2_mean        52.46$\pm$4.12
# louvain_prob_pred_mean                           37.82$\pm$4.84
# bgrl,enc:gcn_ncn,pred:mlp,sbm+random_mean        31.33$\pm$8.88
# bgrl,enc:gcn_ncn,pred:mlp,sbm_fast+random_mean    55.88$\pm$1.8
# bgrl,enc:gcn_ncn,pred:mlp,sbm_fast2_mean         45.33$\pm$7.47
#
# metrics                                                  Hits@50  \
# leiden_prob_pred_mean                             53.17$\pm$1.36
# grace,enc:gcn_ncn,pred:mlp,sbm+random_mean        69.49$\pm$3.82
# grace,enc:gcn_ncn,pred:mlp,sbm_fast+random_mean   66.59$\pm$4.87
# grace,enc:gcn_ncn,pred:mlp,sbm_fast2_mean          69.9$\pm$1.71
# ...
