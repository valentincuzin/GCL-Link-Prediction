# %%
import utils as ut

# %% [markdown]
# # Small Analysis

# %% [markdown]
# ## Facebook Friends

# %%
name = 'test_ctri_facebook_friends_res.csv'
data = ut.res_load(name)
grace, _ = ut.split_methods(data, 'bgrl')
bgrl, _ = ut.split_methods(data, 'grace')

ut.heatmap(grace, 'grace '+name, size=(15,15), variance=True)
ut.heatmap(bgrl, 'bgrl '+name, size=(15,15), variance=True)

# %%
name = 'test_ctri_wiki_science_res.csv'
data = ut.res_load(name)
grace, _ = ut.split_methods(data, 'bgrl')
bgrl, _ = ut.split_methods(data, 'grace')

ut.heatmap(grace, 'grace '+name, size=(15,15), variance=True)
ut.heatmap(bgrl, 'bgrl '+name, size=(15,15), variance=True)

# %%
name = 'test_ctri_crime_res.csv'
data = ut.res_load(name)
grace, _ = ut.split_methods(data, 'bgrl')
bgrl, _ = ut.split_methods(data, 'grace')

ut.heatmap(grace, 'grace '+name, size=(15,15), variance=True)
ut.heatmap(bgrl, 'bgrl '+name, size=(15,15), variance=True)

# %%
name = 'test_ctri_unicodelang_res.csv'
data = ut.res_load(name)
grace, _ = ut.split_methods(data, 'bgrl')
bgrl, _ = ut.split_methods(data, 'grace')

ut.heatmap(grace, 'grace '+name, size=(15,15), variance=True)
ut.heatmap(bgrl, 'bgrl '+name, size=(15,15), variance=True)

# %%
name = 'test_ctri_euroroad_res.csv'
data = ut.res_load(name)
grace, _ = ut.split_methods(data, 'bgrl')
bgrl, _ = ut.split_methods(data, 'grace')

ut.heatmap(grace, 'grace '+name, size=(15,15), variance=True)
ut.heatmap(bgrl, 'bgrl '+name, size=(15,15), variance=True)

# %%
name = 'test_ctri_power_res.csv'
data = ut.res_load(name)
grace, _ = ut.split_methods(data, 'bgrl')
bgrl, _ = ut.split_methods(data, 'grace')

ut.heatmap(grace, 'grace '+name, size=(15,15), variance=True)
ut.heatmap(bgrl, 'bgrl '+name, size=(15,15), variance=True)
