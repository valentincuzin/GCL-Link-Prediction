# %%
import utils as ut

# %%
# BGRL
names = ['FINAL_netscience_res.csv',
'FINAL_power_res.csv',
'FINAL_euroroad_res.csv',
'FINAL_yeast_res.csv',
'FINAL_crime_res.csv',
'FINAL_cora_res.csv',
'FINAL_citeseer_res.csv',
'FINAL_pubmed_res.csv',
'FINAL_computers_res.csv',
'FINAL_photo_res.csv',
'FINAL_cs_res.csv',
'FINAL_struct_cora_res.csv',
'FINAL_struct_citeseer_res.csv',
'FINAL_struct_pubmed_res.csv',
'FINAL_struct_computers_res.csv',
'FINAL_struct_photo_res.csv',
'FINAL_struct_cs_res.csv']

all_data, all_res = ut.mix_dataset(names, 'Hits@50', ['bgrl'])
res = ut.tex_table(all_data, all_res)
print(res.to_latex(
        index=True, formatters={"name": str.upper}, float_format="{:.1f}".format
    ))
# Out:
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllllllllllllll}
# \toprule
#  & FINAL_netscience_res.csv & FINAL_power_res.csv & FINAL_euroroad_res.csv & FINAL_yeast_res.csv & FINAL_crime_res.csv & FINAL_cora_res.csv & FINAL_citeseer_res.csv & FINAL_pubmed_res.csv & FINAL_computers_res.csv & FINAL_photo_res.csv & FINAL_cs_res.csv & FINAL_struct_cora_res.csv & FINAL_struct_citeseer_res.csv & FINAL_struct_pubmed_res.csv & FINAL_struct_computers_res.csv & FINAL_struct_photo_res.csv & FINAL_struct_cs_res.csv \\
# \midrule
# bgrl random & \color{blue}{85.18$\pm$1.28 $\bigstar$} & 29.6$\pm$0.96 & 27.31$\pm$3.89 X & 93.78$\pm$0.54 & \color{blue}{23.73$\pm$2.21 $\bigstar$} & 73.58$\pm$1.44 X & 74.08$\pm$1.06 $\bigstar$ & 61.81$\pm$1.76 X & 18.71$\pm$7.7 X & 35.99$\pm$11.71 X & \color{red}{64.42$\pm$4.93 $\bigstar$} & 50.93$\pm$1.72 X & 49.63$\pm$1.87 X & 38.29$\pm$0.88 & 30.52$\pm$3.62 $\bigstar$ & \color{blue}{46.35$\pm$3.91 $\bigstar$} & \color{violet}{65.79$\pm$0.96 $\bigstar$} \\
# ...

# %%
# full comparatif non attr
names = ['FINAL_netscience_res.csv',
'FINAL_power_res.csv',
'FINAL_euroroad_res.csv',
'FINAL_yeast_res.csv',
'FINAL_crime_res.csv']
filtres = ['baseline','grace','bgrl']
print("                             ROCAUC                      ")
all_data, all_res = ut.mix_dataset(names, 'ROCAUC', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             AP                      ")
all_data, all_res = ut.mix_dataset(names, 'AP', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             Hits@100                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@100', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             Hits@50                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@50', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             Hits@20                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@20', filtres)
display(ut.tex_table(all_data, all_res).T)
# Out:
#                              ROCAUC
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllll}
# \toprule
#  & FINAL_netscience_res.csv & FINAL_power_res.csv & FINAL_euroroad_res.csv & FINAL_yeast_res.csv & FINAL_crime_res.csv \\
# \midrule
# baseline & 92.69$\pm$0.91 & 67.61$\pm$1.0 & 64.32$\pm$1.25 & 97.05$\pm$0.24 & \color{red}{53.34$\pm$2.52 $\bigstar$} \\
# grace random & 90.16$\pm$0.97 & 66.42$\pm$0.96 & 62.79$\pm$2.3 & 96.6$\pm$0.27 & 43.18$\pm$2.55 \\
# grace deg & \color{blue}{94.17$\pm$1.89 $\bigstar$} & \color{red}{74.12$\pm$3.67 $\bigstar$} & \color{red}{68.43$\pm$6.66 $\bigstar$} & \color{violet}{97.75$\pm$0.64 $\bigstar$} & 47.49$\pm$4.77 \\
# grace pr & 88.97$\pm$1.07 & 66.27$\pm$1.27 & \color{violet}{65.6$\pm$4.3} & 97.65$\pm$0.6 $\bigstar$ & 40.68$\pm$2.21 X \\
# grace evc & 90.46$\pm$0.98 & 64.8$\pm$0.53 & \color{blue}{66.5$\pm$5.73} & 96.95$\pm$0.22 & 49.25$\pm$7.52 \\
# grace scom & 91.7$\pm$1.28 & 67.56$\pm$2.16 & 62.73$\pm$3.11 & 97.07$\pm$0.37 & 46.54$\pm$5.69 \\
# ...

# %%
# score attr
names = ['FINAL_cora_res.csv',
'FINAL_citeseer_res.csv',
'FINAL_pubmed_res.csv',
'FINAL_computers_res.csv',
'FINAL_photo_res.csv',
'FINAL_cs_res.csv']
filtres = ['baseline','grace','bgrl']

print("                             ROCAUC                      ")
all_data, all_res = ut.mix_dataset(names, 'ROCAUC', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             AP                      ")
all_data, all_res = ut.mix_dataset(names, 'AP', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             Hits@100                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@100', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             Hits@50                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@50', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             Hits@20                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@20', filtres)
display(ut.tex_table(all_data, all_res).T)
# Out:
#                              ROCAUC
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllll}
# \toprule
#  & FINAL_cora_res.csv & FINAL_citeseer_res.csv & FINAL_pubmed_res.csv & FINAL_computers_res.csv & FINAL_photo_res.csv & FINAL_cs_res.csv \\
# \midrule
# baseline & 90.61$\pm$0.77 & 50.01$\pm$0.02 X & \color{red}{98.29$\pm$0.09 $\bigstar$} & 59.2$\pm$18.41 X & 76.85$\pm$22.69 X & \color{red}{97.8$\pm$0.11 $\bigstar$} \\
# grace random & 91.73$\pm$0.78 & 93.38$\pm$0.6 & 97.5$\pm$0.1 & 87.96$\pm$4.69 & 97.94$\pm$0.16 X & 96.7$\pm$0.15 \\
# grace deg & \color{violet}{93.43$\pm$0.5 $\bigstar$} & \color{red}{94.48$\pm$0.66 $\bigstar$} & 97.65$\pm$0.14 & 86.15$\pm$5.29 & 97.9$\pm$0.27 X & 96.77$\pm$0.17 \\
# grace pr & 93.39$\pm$0.47 $\bigstar$ & 94.08$\pm$0.46 $\bigstar$ & \color{blue}{97.66$\pm$0.14} & 85.53$\pm$5.93 & 98.05$\pm$0.19 & 96.77$\pm$0.16 \\
# ...

# %%
# score struct
names = ['FINAL_struct_cora_res.csv',
'FINAL_struct_citeseer_res.csv',
'FINAL_struct_pubmed_res.csv',
'FINAL_struct_computers_res.csv',
'FINAL_struct_photo_res.csv',
'FINAL_struct_cs_res.csv']
filtres = ['grace','bgrl']
print("                             ROCAUC                      ")
all_data, all_res = ut.mix_dataset(names, 'ROCAUC', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             AP                      ")
all_data, all_res = ut.mix_dataset(names, 'AP', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             Hits@100                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@100', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             Hits@50                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@50', filtres)
display(ut.tex_table(all_data, all_res).T)
print("                             Hits@20                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@20', filtres)
display(ut.tex_table(all_data, all_res).T)
# Out:
#                              ROCAUC
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllll}
# \toprule
#  & FINAL_struct_cora_res.csv & FINAL_struct_citeseer_res.csv & FINAL_struct_pubmed_res.csv & FINAL_struct_computers_res.csv & FINAL_struct_photo_res.csv & FINAL_struct_cs_res.csv \\
# \midrule
# grace random & 78.14$\pm$0.73 & 74.3$\pm$1.75 & 72.9$\pm$0.55 & \color{violet}{98.62$\pm$0.04} & \color{violet}{98.9$\pm$0.04} & 94.1$\pm$0.26 \\
# grace deg & \color{red}{83.5$\pm$1.03 $\bigstar$} & \color{red}{78.6$\pm$2.08 $\bigstar$} & \color{violet}{74.47$\pm$1.15} & 98.47$\pm$0.13 & 98.89$\pm$0.05 & \color{blue}{95.12$\pm$0.67 $\bigstar$} \\
# grace pr & 78.34$\pm$1.28 & 71.8$\pm$2.17 & 72.56$\pm$0.89 & \color{blue}{98.66$\pm$0.05 $\bigstar$} & \color{blue}{98.92$\pm$0.04 $\bigstar$} & 94.74$\pm$0.53 \\
# ...

# %%
# sbm
names = ['FINAL_SBM_cora_res.csv',
'FINAL_SBM_citeseer_res.csv',
'FINAL_SBM_netscience_res.csv',
'FINAL_SBM_power_res.csv',
'FINAL_SBM_euroroad_res.csv',
'FINAL_SBM_yeast_res.csv',
'FINAL_SBM_crime_res.csv']
names_base = ['FINAL_cora_res.csv',
'FINAL_citeseer_res.csv',
'FINAL_netscience_res.csv',
'FINAL_power_res.csv',
'FINAL_euroroad_res.csv',
'FINAL_yeast_res.csv',
'FINAL_crime_res.csv']

all_data_base, all_res_base = ut.mix_dataset(names_base, 'Hits@50',['baseline','bgrl', 'grace'], ['evc', 'pr', "\+"])
all_data_base.index = ["cora", "citeseer", "netscience", "power", "euroroad", "yeast", "crime"]
all_res_base.index = ["cora", "citeseer", "netscience", "power", "euroroad", "yeast", "crime"]

print("                             Hits@50                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@50')
all_data.index = ["cora", "citeseer", "netscience", "power", "euroroad", "yeast", "crime"]
all_res.index = ["cora", "citeseer", "netscience", "power", "euroroad", "yeast", "crime"]
all_data = all_data_base.join(all_data)
all_res = all_res_base.join(all_res)
display(ut.tex_table(all_data, all_res).T)


# print("                             ROCAUC                      ")
# all_data, all_res = ut.mix_dataset(names, 'ROCAUC',filtres)
# display(ut.tex_table(all_data, all_res).T)
# print("                             AP                      ")
# all_data, all_res = ut.mix_dataset(names, 'AP', filtres)
# display(ut.tex_table(all_data, all_res).T)
# print("                             Hits@100                      ")
# all_data, all_res = ut.mix_dataset(names, 'Hits@100', filtres)
# display(ut.tex_table(all_data, all_res).T)
# print("                             Hits@50                      ")
# all_data, all_res = ut.mix_dataset(names, 'Hits@50', filtres)
# display(ut.tex_table(all_data, all_res).T)
# print("                             Hits@20                      ")
# all_data, all_res = ut.mix_dataset(names, 'Hits@20', filtres)
# display(ut.tex_table(all_data, all_res).T)
# Out:
#                              Hits@50
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
# \toprule
#  & cora & citeseer & netscience & power & euroroad & yeast & crime \\
# \midrule
# baseline & 71.55$\pm$1.75 & 0.0$\pm$0.0 X & 85.18$\pm$1.85 & 32.24$\pm$0.75 & 36.71$\pm$3.26 & 93.98$\pm$0.55 & 23.02$\pm$2.9 \\
# grace random & 75.85$\pm$1.75 & 77.99$\pm$1.21 $\bigstar$ & 84.34$\pm$1.29 & 36.05$\pm$1.17 & 37.42$\pm$2.96 & 94.28$\pm$0.28 & 18.34$\pm$2.03 X \\
# grace deg & 73.9$\pm$2.04 & \color{red}{79.16$\pm$2.24 $\bigstar$} & 86.28$\pm$2.0 & 36.46$\pm$1.26 & 43.46$\pm$7.72 & 93.66$\pm$0.56 & 21.05$\pm$3.22 \\
# grace scom & 76.3$\pm$2.02 & \color{blue}{78.6$\pm$1.31 $\bigstar$} & 84.32$\pm$1.3 & 36.34$\pm$1.11 & 36.22$\pm$3.33 & 94.37$\pm$0.24 & 18.85$\pm$3.06 X \\
# bgrl random & 73.58$\pm$1.44 & 74.08$\pm$1.06 & 85.18$\pm$1.28 & 29.6$\pm$0.96 X & 27.31$\pm$3.89 X & 93.78$\pm$0.54 & 23.73$\pm$2.21 \\
# ...

# %%
# reconstruction
names = [
'R_FINAL_cora_res.csv',
'R_FINAL_citeseer_res.csv',
'R_FINAL_netscience_res.csv',
'R_FINAL_power_res.csv',
'R_FINAL_euroroad_res.csv',
'R_FINAL_yeast_res.csv',
'R_FINAL_crime_res.csv']
names_base = ['FINAL_cora_res.csv',
'FINAL_citeseer_res.csv',
'FINAL_netscience_res.csv',
'FINAL_power_res.csv',
'FINAL_euroroad_res.csv',
'FINAL_yeast_res.csv',
'FINAL_crime_res.csv']

all_data_base, all_res_base = ut.mix_dataset(names_base, 'Hits@50',['baseline','bgrl', 'grace'], ['evc', 'pr','\+'])
all_data_base.index = ["cora", "citeseer", "netscience", "power", "euroroad", "yeast", "crime"]
all_res_base.index = ["cora", "citeseer", "netscience", "power", "euroroad", "yeast", "crime"]

print("                             Hits@50                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@50', filtre2=['\+'])
all_data.index = ["cora", "citeseer", "netscience", "power", "euroroad", "yeast", "crime"]
all_res.index = ["cora", "citeseer", "netscience", "power", "euroroad", "yeast", "crime"]
all_data = all_data_base.join(all_data)
all_res = all_res_base.join(all_res)
res = ut.tex_table(all_data, all_res).T
res = res.reindex(['baseline', 'grace random', 'grace deg', 'grace scom', 'grace rjc', 'grace raa', 'grace rra',
				   'bgrl random', 'bgrl deg', 'bgrl scom', 'bgrl rjc', 'bgrl raa', 'bgrl rra'])
print(res.to_latex(
        index=True, formatters={"name": str.upper}, float_format="{:.1f}".format
    ))
# Out:
#                              Hits@50
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
# \toprule
#  & cora & citeseer & netscience & power & euroroad & yeast & crime \\
# \midrule
# baseline & 71.55$\pm$1.75 X & 0.0$\pm$0.0 X & \color{violet}{85.18$\pm$1.85} & 32.24$\pm$0.75 & 36.71$\pm$3.26 & 93.98$\pm$0.55 & \color{blue}{23.02$\pm$2.9 $\bigstar$} \\
# grace random & 75.85$\pm$1.75 & 77.99$\pm$1.21 & 84.34$\pm$1.29 & \color{violet}{36.05$\pm$1.17 $\bigstar$} & \color{violet}{37.42$\pm$2.96 $\bigstar$} & \color{blue}{94.28$\pm$0.28 $\bigstar$} & 18.34$\pm$2.03 \\
# grace deg & 73.9$\pm$2.04 & \color{blue}{79.16$\pm$2.24 $\bigstar$} & \color{blue}{86.28$\pm$2.0 $\bigstar$} & \color{red}{36.46$\pm$1.26 $\bigstar$} & \color{red}{43.46$\pm$7.72 $\bigstar$} & 93.66$\pm$0.56 & 21.05$\pm$3.22 \\
# ...

# %%
# Â
names = [
'A2_FINAL_cora_res.csv',
'A2_FINAL_netscience_res.csv',
'A2_FINAL_euroroad_res.csv',
'A2_FINAL_yeast_res.csv',
'A2_FINAL_crime_res.csv']
names_base = ['FINAL_cora_res.csv',
'FINAL_netscience_res.csv',
'FINAL_euroroad_res.csv',
'FINAL_yeast_res.csv',
'FINAL_crime_res.csv']

all_data_base, all_res_base = ut.mix_dataset(names_base, 'Hits@50',['baseline','bgrl', 'grace'], ['evc', 'pr', 'scom', '\+'])
all_data_base.index = ["cora", "netscience", "euroroad", "yeast", "crime"]
all_res_base.index = ["cora", "netscience", "euroroad", "yeast", "crime"]

print("                             Hits@50                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@50', filtre2=['sbm', 'raa'])
all_data.index = ["cora", "netscience", "euroroad", "yeast", "crime"]
all_res.index = ["cora", "netscience", "euroroad", "yeast", "crime"]
all_data = all_data_base.join(all_data)
all_res = all_res_base.join(all_res)
res = ut.tex_table(all_data, all_res).T
res = res.reindex(['baseline', 'grace random', 'grace deg', 'a2grace random', 'a2grace deg',
				   'bgrl random', 'bgrl deg', 'a2bgrl random', 'a2bgrl deg'])
res
print(res.to_latex(
        index=True, formatters={"name": str.upper}, float_format="{:.1f}".format
    ))
# Out:
#                              Hits@50
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllll}
# \toprule
#  & cora & netscience & euroroad & yeast & crime \\
# \midrule
# baseline & 71.55$\pm$1.75 X & 85.18$\pm$1.85 & 36.71$\pm$3.26 & 93.98$\pm$0.55 & \color{violet}{23.02$\pm$2.9} \\
# grace random & \color{violet}{75.85$\pm$1.75 $\bigstar$} & 84.34$\pm$1.29 X & 37.42$\pm$2.96 $\bigstar$ & \color{violet}{94.28$\pm$0.28} & 18.34$\pm$2.03 X \\
# grace deg & 73.9$\pm$2.04 & \color{violet}{86.28$\pm$2.0} & \color{red}{43.46$\pm$7.72 $\bigstar$} & 93.66$\pm$0.56 X & 21.05$\pm$3.22 \\
# bgrl random & 73.58$\pm$1.44 & 85.18$\pm$1.28 & 27.31$\pm$3.89 X & 93.78$\pm$0.54 X & \color{blue}{23.73$\pm$2.21 $\bigstar$} \\
# bgrl deg & \color{red}{77.49$\pm$1.21 $\bigstar$} & \color{blue}{86.95$\pm$2.33 $\bigstar$} & \color{violet}{38.94$\pm$9.26 $\bigstar$} & 94.26$\pm$0.48 & 22.85$\pm$3.54 \\
# ...

# %%
# Â
names = [
'A2_FINAL_cora_res.csv',
'A2_FINAL_netscience_res.csv',
'A2_FINAL_euroroad_res.csv',
'A2_FINAL_yeast_res.csv',
'A2_FINAL_crime_res.csv']
names_base = ['FINAL_SBM_cora_res.csv',
'FINAL_SBM_netscience_res.csv',
'FINAL_SBM_euroroad_res.csv',
'FINAL_SBM_yeast_res.csv',
'FINAL_SBM_crime_res.csv']

all_data_base, all_res_base = ut.mix_dataset(names_base, 'Hits@50',['baseline','sbm+', 'grace'], ['sbm2','scom'])
all_data_base.index = ["cora", "netscience", "euroroad", "yeast", "crime"]
all_res_base.index = ["cora", "netscience", "euroroad", "yeast", "crime"]

print("                             Hits@50                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@50', ['sbm'], ['raa'])
all_data.index = ["cora", "netscience", "euroroad", "yeast", "crime"]
all_res.index = ["cora", "netscience", "euroroad", "yeast", "crime"]
all_data = all_data_base.join(all_data)
all_res = all_res_base.join(all_res)
res = ut.tex_table(all_data, all_res).T
res = res.reindex(['grace sbm+random', 'grace sbm+deg', 'a2grace sbm+random', 'a2grace sbm+deg', 'bgrl sbm+random', 'bgrl sbm+deg', 'a2bgrl sbm+random', 'a2bgrl sbm+deg'])
res
print(res.to_latex(
        index=True, formatters={"name": str.upper}, float_format="{:.1f}".format
    ))
# Out:
#                              Hits@50
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllll}
# \toprule
#  & cora & netscience & euroroad & yeast & crime \\
# \midrule
# grace sbm & 76.28$\pm$1.69 & 91.42$\pm$1.03 & 69.68$\pm$2.71 & 92.08$\pm$0.61 X & 31.53$\pm$4.0 \\
# grace sbm+random & \color{blue}{77.75$\pm$1.66} & \color{blue}{92.43$\pm$0.97 $\bigstar$} & \color{blue}{75.37$\pm$2.89 $\bigstar$} & 93.56$\pm$0.68 & \color{blue}{33.69$\pm$4.59 $\bigstar$} \\
# grace sbm+deg & \color{violet}{77.68$\pm$2.05} & \color{violet}{92.23$\pm$0.88 $\bigstar$} & \color{violet}{74.06$\pm$4.63 $\bigstar$} & \color{blue}{94.98$\pm$0.54 $\bigstar$} & \color{violet}{32.37$\pm$3.48} \\
# bgrl sbm & 72.79$\pm$1.71 X & 88.52$\pm$2.02 X & 47.84$\pm$4.25 X & 93.75$\pm$0.59 & 26.92$\pm$2.38 \\
# bgrl sbm+random & 75.75$\pm$1.95 & 89.36$\pm$1.35 & 59.51$\pm$4.25 & 93.91$\pm$0.48 & 26.64$\pm$3.0 \\
# ...

# %%
# Link-loss
names = [
'L_FINAL_cora_res.csv',
'L_FINAL_netscience_res.csv',
'L_FINAL_power_res.csv',
'L_FINAL_euroroad_res.csv',
'L_FINAL_yeast_res.csv',
'L_FINAL_crime_res.csv']
names_base = [
'FINAL_cora_res.csv',
'FINAL_netscience_res.csv',
'FINAL_power_res.csv',
'FINAL_euroroad_res.csv',
'FINAL_yeast_res.csv',
'FINAL_crime_res.csv']


all_data_base, all_res_base = ut.mix_dataset(names_base, 'Hits@50',['baseline','bgrl', 'grace'], ['evc', 'pr', 'scom', '\+'])


all_data_base.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]
all_res_base.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]


print("                             Hits@50                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@50', filtre2=['sbm','raa'])
all_data.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]
all_res.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]
all_data1 = all_data_base.join(all_data)
all_res1 = all_res_base.join(all_res)


res1 = ut.tex_table(all_data1, all_res1).T
res1
print(res1.to_latex(
        index=True, formatters={"name": str.upper}, float_format="{:.1f}".format
    ))
# Out:
#                              Hits@50
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllll}
# \toprule
#  & cora & netscience & power & euroroad & yeast & crime \\
# \midrule
# baseline & 71.55$\pm$1.75 X & \color{violet}{85.18$\pm$1.85} & 32.24$\pm$0.75 & 36.71$\pm$3.26 & 93.98$\pm$0.55 $\bigstar$ & \color{violet}{23.02$\pm$2.9} \\
# grace random & \color{violet}{75.85$\pm$1.75 $\bigstar$} & 84.34$\pm$1.29 X & \color{blue}{36.05$\pm$1.17 $\bigstar$} & 37.42$\pm$2.96 $\bigstar$ & \color{red}{94.28$\pm$0.28 $\bigstar$} & 18.34$\pm$2.03 X \\
# grace deg & 73.9$\pm$2.04 & \color{blue}{86.28$\pm$2.0 $\bigstar$} & \color{red}{36.46$\pm$1.26 $\bigstar$} & \color{red}{43.46$\pm$7.72 $\bigstar$} & 93.66$\pm$0.56 & 21.05$\pm$3.22 \\
# bgrl random & 73.58$\pm$1.44 & 85.18$\pm$1.28 & 29.6$\pm$0.96 X & 27.31$\pm$3.89 X & 93.78$\pm$0.54 & \color{blue}{23.73$\pm$2.21 $\bigstar$} \\
# ...

# %%
# Link-loss
names = [
'L_FINAL_cora_res.csv',
'L_FINAL_netscience_res.csv',
'L_FINAL_power_res.csv',
'L_FINAL_euroroad_res.csv',
'L_FINAL_yeast_res.csv',
'L_FINAL_crime_res.csv']

names_sbm = [
'FINAL_SBM_cora_res.csv',
'FINAL_SBM_netscience_res.csv',
'FINAL_SBM_power_res.csv',
'FINAL_SBM_euroroad_res.csv',
'FINAL_SBM_yeast_res.csv',
'FINAL_SBM_crime_res.csv']

all_data_sbm, all_res_sbm = ut.mix_dataset(names_sbm, 'Hits@50', ['\+deg', '\+random'])

all_data_sbm.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]
all_res_sbm.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]


print("                             Hits@50                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@50', filtre=['sbm'], filtre2=['raa'])
all_data.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]
all_res.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]

all_data2 = all_data.join(all_data_sbm)
all_res2 = all_res.join(all_res_sbm)

res2 = ut.tex_table(all_data2, all_res2).T
res2
print(res2.to_latex(
        index=True, formatters={"name": str.upper}, float_format="{:.1f}".format
    ))
# Out:
#                              Hits@50
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllll}
# \toprule
#  & cora & netscience & power & euroroad & yeast & crime \\
# \midrule
# lgrace sbm+random & 53.68$\pm$3.8 X & 82.99$\pm$2.2 X & 11.29$\pm$2.06 X & 24.35$\pm$3.65 X & 92.99$\pm$0.83 X & 28.14$\pm$7.05 \\
# lgrace sbm+deg & 53.31$\pm$5.71 X & 82.52$\pm$2.6 X & 12.38$\pm$3.17 X & 24.06$\pm$3.84 X & 92.68$\pm$0.58 X & 28.14$\pm$7.05 \\
# lbgrl sbm+random & 67.0$\pm$2.05 & 88.56$\pm$1.85 & 24.97$\pm$2.4 & 35.55$\pm$2.94 & 93.73$\pm$0.51 & \color{violet}{28.24$\pm$7.84} \\
# lbgrl sbm+deg & 62.23$\pm$3.06 X & 87.5$\pm$1.54 & 16.88$\pm$7.69 X & 32.05$\pm$7.02 X & 92.81$\pm$1.43 X & 27.32$\pm$5.37 X \\
# grace sbm+random & \color{blue}{77.75$\pm$1.66 $\bigstar$} & \color{red}{92.43$\pm$0.97 $\bigstar$} & \color{red}{63.01$\pm$2.91 $\bigstar$} & \color{red}{75.37$\pm$2.89 $\bigstar$} & 93.56$\pm$0.68 & \color{red}{33.69$\pm$4.59 $\bigstar$} \\
# ...

# %%
# Link-loss
names = [
'L_FINAL_cora_res.csv',
'L_FINAL_netscience_res.csv',
'L_FINAL_power_res.csv',
'L_FINAL_euroroad_res.csv',
'L_FINAL_yeast_res.csv',
'L_FINAL_crime_res.csv']

names_r = [
'R_FINAL_cora_res.csv',
'R_FINAL_netscience_res.csv',
'R_FINAL_power_res.csv',
'R_FINAL_euroroad_res.csv',
'R_FINAL_yeast_res.csv',
'R_FINAL_crime_res.csv'
]
all_data_r, all_res_r = ut.mix_dataset(names_r, 'Hits@50',['raa'], ['\+'])


all_data_r.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]
all_res_r.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]


print("                             Hits@50                      ")
all_data, all_res = ut.mix_dataset(names, 'Hits@50', filtre=['raa'], filtre2=['sbm'])
all_data.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]
all_res.index = ["cora", "netscience", "power", "euroroad", "yeast", "crime"]

all_data = all_data.join(all_data_r)
all_res = all_res.join(all_res_r)
res = ut.tex_table(all_data).T
res
print(res.to_latex(
        index=True, formatters={"name": str.upper}, float_format="{:.1f}".format
    ))
# Out:
#                              Hits@50
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllllll}
# \toprule
#  & cora & netscience & power & euroroad & yeast & crime \\
# \midrule
# lgrace raa & \color{violet}{73.46$\pm$1.19} & \color{red}{85.09$\pm$1.19} & \color{red}{35.51$\pm$0.82} & \color{red}{38.48$\pm$4.51} & 93.81$\pm$0.47 & \color{blue}{18.47$\pm$2.24} \\
# lbgrl raa & \color{red}{77.23$\pm$1.65} & \color{violet}{84.14$\pm$1.94} & \color{violet}{32.49$\pm$1.12} & \color{blue}{38.3$\pm$6.45} & \color{blue}{94.08$\pm$0.37} & \color{red}{25.02$\pm$5.46} \\
# grace raa & \color{blue}{76.1$\pm$1.72} & 83.83$\pm$1.23 & \color{blue}{35.18$\pm$1.0} & \color{violet}{34.17$\pm$2.92} & \color{red}{94.25$\pm$0.29} & 16.51$\pm$2.51 \\
# bgrl raa & 71.72$\pm$1.14 & \color{blue}{84.18$\pm$1.39} & 29.1$\pm$0.74 & 24.35$\pm$1.04 & \color{violet}{94.08$\pm$0.48} & \color{violet}{17.32$\pm$1.84} \\
# \bottomrule
# \end{tabular}
#
# }
# \begin{tabular}{lllllll}
# \toprule
# ...
