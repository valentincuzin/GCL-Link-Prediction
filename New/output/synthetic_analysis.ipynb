# %%
import utils as ut

# %% [markdown]
# # Synthetic Analysis

# %% [markdown]
# ## Synthetic 1
# ```python
# data = _LFR_gen(400, 4, 3, 0.2, average_degree=10, min_community=75)
# ```

# %%
data = ut.res_load('final_synthetic_1_res.csv')
grace, _ = ut.split_methods(data, 'bgrl')
bgrl, _ = ut.split_methods(data, 'grace')

ut.heatmap(grace, 'synthetic_1 final grace', size=(15,15), variance=True)
ut.heatmap(bgrl, 'synthetic_1 final bgrl', size=(15,15), variance=True)

# %%
data = ut.res_load('final_synthetic_2_res.csv')
grace, _ = ut.split_methods(data, 'bgrl')
bgrl, _ = ut.split_methods(data, 'grace')

ut.heatmap(grace, 'synthetic_2 final grace', size=(15,15), variance=True)
ut.heatmap(bgrl, 'synthetic_2 final bgrl', size=(15,15), variance=True)

# %%
data = ut.res_load('final_synthetic_3_res.csv')
grace, _ = ut.split_methods(data, 'bgrl')
bgrl, _ = ut.split_methods(data, 'grace')

ut.heatmap(grace, 'synthetic_3 final grace', size=(15,15), variance=True)
ut.heatmap(bgrl, 'synthetic_3 final bgrl', size=(15,15), variance=True)
