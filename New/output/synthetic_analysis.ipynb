# %%
import utils as ut

# %% [markdown]
# # Synthetic Analysis

# %% [markdown]
# ## Synthetic 1
# ```python
# data = _LFR_gen(400, 4, 3, 0.2, average_degree=10, min_community=75)
# ```

# %%
import pandas as pd
data1 = ut.res_load('final_synthetic_1_res.csv')
data2 = ut.res_load('final_synthetic_2_res.csv')
data3 = ut.res_load('final_synthetic_3_res.csv')
Final = pd.DataFrame({'synthetic 1': data1['Hits@50'], 'synthetic 2': data2['Hits@50'], 'synthetic 3': data3['Hits@50']})
Final
# Out:
# could not convert string to float: '40.92$\\pm$5.48'
# could not convert string to float: '35.67$\\pm$8.84'
# could not convert string to float: '35.21$\\pm$5.64'
# could not convert string to float: '38.35$\\pm$9.79'
# could not convert string to float: '35.07$\\pm$7.16'
# could not convert string to float: '38.1$\\pm$4.16'
# could not convert string to float: '35.7$\\pm$7.65'
# could not convert string to float: '33.87$\\pm$8.69'
# could not convert string to float: '34.96$\\pm$7.12'
# could not convert string to float: '40.28$\\pm$6.82'
# could not convert string to float: '32.11$\\pm$7.27'
# could not convert string to float: '35.56$\\pm$8.06'
# could not convert string to float: '34.15$\\pm$9.56'
# could not convert string to float: '33.27$\\pm$8.47'
# could not convert string to float: '39.72$\\pm$7.98'
# could not convert string to float: '37.15$\\pm$6.63'
# could not convert string to float: '37.82$\\pm$7.96'
# could not convert string to float: '31.27$\\pm$9.04'
# ...

# %%
data = ut.res_load('final_synthetic_1_res.csv')
data = data[~data.index.str.contains('lgrace')]
data = data[~data.index.str.contains('lbgrl')]
data = data[~data.index.str.contains('scom')]
data = data.rename(index={'baseline': 'E2E-GCN'})
ut.heatmap(data, '', size=(13,13), variance=True)
# Out:
# could not convert string to float: '40.92$\\pm$5.48'
# could not convert string to float: '35.67$\\pm$8.84'
# could not convert string to float: '35.21$\\pm$5.64'
# could not convert string to float: '38.35$\\pm$9.79'
# could not convert string to float: '35.07$\\pm$7.16'
# could not convert string to float: '38.1$\\pm$4.16'
# could not convert string to float: '35.7$\\pm$7.65'
# could not convert string to float: '33.87$\\pm$8.69'
# could not convert string to float: '34.96$\\pm$7.12'
# could not convert string to float: '40.28$\\pm$6.82'
# could not convert string to float: '32.11$\\pm$7.27'
# could not convert string to float: '35.56$\\pm$8.06'
# could not convert string to float: '34.15$\\pm$9.56'
# could not convert string to float: '33.27$\\pm$8.47'
# could not convert string to float: '39.72$\\pm$7.98'
# could not convert string to float: '37.15$\\pm$6.63'
# could not convert string to float: '37.82$\\pm$7.96'
# could not convert string to float: '31.27$\\pm$9.04'
# ...

# %%
data = ut.res_load('final_synthetic_2_res.csv')
data = data[~data.index.str.contains('lgrace')]
data = data[~data.index.str.contains('lbgrl')]
data = data[~data.index.str.contains('scom')]
data = data.rename(index={'baseline': 'E2E-GCN'})
ut.heatmap(data, '', size=(13,13), variance=True)
# Out:
# could not convert string to float: '0.0$\\pm$0.0'
# could not convert string to float: '9.48$\\pm$1.89'
# could not convert string to float: '8.57$\\pm$1.9'
# could not convert string to float: '9.73$\\pm$2.58'
# could not convert string to float: '7.19$\\pm$1.33'
# could not convert string to float: '8.85$\\pm$1.23'
# could not convert string to float: '7.29$\\pm$1.85'
# could not convert string to float: '8.51$\\pm$1.88'
# could not convert string to float: '9.37$\\pm$1.93'
# could not convert string to float: '8.91$\\pm$2.13'
# could not convert string to float: '7.56$\\pm$1.59'
# could not convert string to float: '8.3$\\pm$1.54'
# could not convert string to float: '6.97$\\pm$1.99'
# could not convert string to float: '7.85$\\pm$1.51'
# could not convert string to float: '7.85$\\pm$2.41'
# could not convert string to float: '8.46$\\pm$2.01'
# could not convert string to float: '8.91$\\pm$2.71'
# could not convert string to float: '7.74$\\pm$2.17'
# ...

# %%
data = ut.res_load('final_synthetic_3_res.csv')
data = data[~data.index.str.contains('lgrace')]
data = data[~data.index.str.contains('lbgrl')]
data = data[~data.index.str.contains('scom')]
data = data.rename(index={'baseline': 'E2E-GCN'})
ut.heatmap(data, '', size=(13,13), variance=True)
# Out:
# could not convert string to float: '45.19$\\pm$6.4'
# could not convert string to float: '25.98$\\pm$3.96'
# could not convert string to float: '38.7$\\pm$4.29'
# could not convert string to float: '38.59$\\pm$4.92'
# could not convert string to float: '23.06$\\pm$3.2'
# could not convert string to float: '21.98$\\pm$6.56'
# could not convert string to float: '28.37$\\pm$7.27'
# could not convert string to float: '28.6$\\pm$6.07'
# could not convert string to float: '36.4$\\pm$4.87'
# could not convert string to float: '40.65$\\pm$4.47'
# could not convert string to float: '18.72$\\pm$2.97'
# could not convert string to float: '22.48$\\pm$5.59'
# could not convert string to float: '16.2$\\pm$1.8'
# could not convert string to float: '18.4$\\pm$1.72'
# could not convert string to float: '30.97$\\pm$6.13'
# could not convert string to float: '36.82$\\pm$6.23'
# could not convert string to float: '8.09$\\pm$2.23'
# could not convert string to float: '6.25$\\pm$2.57'
# ...
