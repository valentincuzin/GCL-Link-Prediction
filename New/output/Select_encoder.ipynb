# %%
import utils as ut

# %%
names = ['Enc_cora_res.csv', 'Enc_citeseer_res.csv', 'Enc_NS_res.csv', 'Enc_Power_res.csv']
means, res = ut.mix_dataset(names, 'Hits@50')
display(ut.average_methods(means).sort_values())
big_tab = ut.tex_table(means, res).T
big_tab
# Out:
# lbgrl_enc:gcn_grace_pred:mlp_random_mean    33.8675
# grace_enc:gcn_grace_pred:mlp_random_mean    40.4400
# lbgrl_enc:gcn_bgrl_pred:mlp_random_mean     46.1800
# grace_enc:gcn_ncn_pred:mlp_random_mean      48.6500
# lbgrl_enc:gcn_ncn_pred:mlp_random_mean      58.2900
# grace_enc:gcn_bgrl_pred:mlp_random_mean     58.5600
# bgrl_enc:gcn_grace_pred:mlp_random_mean     58.8050
# bgrl_enc:gcn_ncn_pred:mlp_random_mean       63.0600
# bgrl_enc:gcn_bgrl_pred:mlp_random_mean      64.9525
# dtype: float64
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllll}
# \toprule
#  & Enc_cora_res.csv & Enc_citeseer_res.csv & Enc_NS_res.csv & Enc_Power_res.csv \\
# \midrule
# grace enc:gcn grace pred:mlp random & \color{red}{72.11$\pm$2.71 $\bigstar$} & 2.24$\pm$2.76 X & \color{blue}{87.41$\pm$1.09 $\bigstar$} & 0.0$\pm$0.0 X \\
# grace enc:gcn bgrl pred:mlp random & \color{blue}{69.42$\pm$1.92 $\bigstar$} & \color{violet}{75.87$\pm$1.85} & 63.91$\pm$3.55 X & 25.04$\pm$5.04 \\
# ...

# %%
names = ['Enc_cora_res.csv', 'Enc_citeseer_res.csv', 'Enc_NS_res.csv', 'Enc_Power_res.csv']
means, res = ut.mix_dataset(names, 'Hits@100')
big_tab = ut.tex_table(means, res).T
big_tab
# Out:
# \resizebox{\textwidth}{!}{
# \begin{tabular}{lllll}
# \toprule
#  & Enc_cora_res.csv & Enc_citeseer_res.csv & Enc_NS_res.csv & Enc_Power_res.csv \\
# \midrule
# grace enc:gcn grace pred:mlp random & \color{blue}{78.46$\pm$1.93 $\bigstar$} & 17.43$\pm$31.5 X & \color{blue}{89.93$\pm$0.93 $\bigstar$} & 4.13$\pm$8.25 X \\
# grace enc:gcn bgrl pred:mlp random & \color{violet}{77.95$\pm$1.47 $\bigstar$} & 83.25$\pm$1.78 & 73.61$\pm$1.97 X & \color{violet}{31.73$\pm$2.54} \\
# grace enc:gcn ncn pred:mlp random & 64.28$\pm$32.24 $\bigstar$ & \color{blue}{90.55$\pm$0.37 $\bigstar$} & 86.5$\pm$3.49 & 29.56$\pm$1.8 \\
# bgrl enc:gcn grace pred:mlp random & 72.76$\pm$2.92 & \color{violet}{84.46$\pm$1.97} & 68.69$\pm$29.52 & 29.3$\pm$14.72 \\
# bgrl enc:gcn bgrl pred:mlp random & 74.35$\pm$1.56 & 73.03$\pm$15.66 & \color{red}{91.64$\pm$1.58 $\bigstar$} & \color{red}{46.07$\pm$3.17 $\bigstar$} \\
# ...
